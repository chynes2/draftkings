# %%
import pandas as pd
import re

# %%
url_dict = {'fantasy': 'https://www.footballdb.com/fantasy-football/index.html?pos=QB%2CRB%2CWR%2CTE&yr=2018&wk=all&rules=1',
            'QB': 'https://www.footballdb.com/stats/stats.html?mode=P&lg=NFL',
            'RB': 'https://www.footballdb.com/stats/stats.html?lg=NFL&yr=2018&type=reg&mode=R&conf=&limit=all',
            'WR/TE': 'https://www.footballdb.com/stats/stats.html?lg=NFL&yr=2018&type=reg&mode=C&conf=&limit=all'}

# %%
def split_name(name):
    if re.search('(Jr\.)[A-Z]\.', name):
        s = re.split('(Jr\.)[A-Z]\.', name)
        return(s[0])
    elif re.search('([a-z])[A-Z]\.', name):
        s = re.split('([a-z])[A-Z]\.', name)
        return(s[0] + s[1])
    elif re.search('(IV?I?I?)[A-Z]\.', name):
        s = re.split('(IV?I?I?)[A-Z]\.', name)
        return(s[0])
    else:
        s = ['------------------', name]
        return(s[0] + s[1])

def split_names(df, col_name):
    new_series = []
    names = df[col_name]
    for name in names.values:
        new_series.append((split_name(name)))
    return(pd.Series(new_series).str.strip())

def add_stats(main_df, position):
    """Adds more player stats to the main fantasy stats dataframe.
    
    Args:
    main_df -- (pd.DataFrame) the dataframe you want to add stats to
    position -- (str) one of ['QB', 'RB', 'WR/TE']
    """
    url = url_dict[position]
    df = pd.read_html(url, header=0)[0]
    df['position'] = position

    df['player'] = split_names(df, 'Player')
    del df['Player']

    main_df = pd.merge(main_df, df, on='player', how='outer')
    
    coalesce_cols = [i for i in main_df.columns if '_x' in i]
    for col in coalesce_cols:
        main_df[col[:-2]] = main_df[col].combine_first(main_df[col[:-2]+'_y'])
        del main_df[col]
        del main_df[col[:-2]+'_y']
        
    return(main_df)

def clean_dk_name(name):
    if name[-3:] == 'Jr.':
        return(name[:-4])
    else:
        return(name)
    
def clean_dk_names(df):
    new_series = []
    names = df['Name']
    for name in names.values:
        new_series.append((clean_dk_name(name)))
    return(pd.Series(new_series))

# %%
## Read in fantasy data
url = url_dict['fantasy']
stats = pd.read_html(url, header=1)[0].iloc[:, :-1]

cols = ['player', 'bye_wk', 'fantasy_pts', 'pass_att', 'pass_cmp', 'pass_yds', 'pass_td', 'pass_int', 'pass_2pt', 
        'rush_att', 'rush_yds', 'rush_td', 'rush_2pt', 'rec_rcp', 'rec_yds', 'rec_td', 'rec_2pt', 'fumbles_lost']
stats.columns = cols
cols = ['player', 'bye_wk', 'fantasy_pts','pass_2pt', 'rush_2pt','rec_2pt', 'fumbles_lost']
stats = stats[cols]

stats['player'] = split_names(stats, 'player')

# %%
## Add stats
stats = add_stats(stats, 'QB')
stats = add_stats(stats, 'RB')
stats = add_stats(stats, 'WR/TE')

# %%
stats.shape
# Out:
# (422, 29)

# %% [markdown]
# ***

# %%
salaries = pd.read_csv('DKSalaries.csv')
salaries['Name'] = salaries['Name'].str.rstrip('I ')
salaries['Name'] = clean_dk_names(salaries)

df = pd.merge(salaries[['Name', 'Salary', 'Position', 'TeamAbbrev', 'AvgPointsPerGame']],
         stats,
         left_on='Name', right_on='player', how='inner')

# %%
df
# Out:
#                     Name  Salary Position TeamAbbrev  AvgPointsPerGame  \
# 0            Todd Gurley    9400       RB        LAR             28.30
# 1          Antonio Brown    9100       WR        PIT             18.55
# 2          Melvin Gordon    8600       RB        LAC             27.88
# 3            Julio Jones    8500       WR        ATL             21.58
# 4    Christian McCaffrey    8000       RB        CAR             23.27
# 5          Odell Beckham    8000       WR        NYG             17.75
# 6           Keenan Allen    7800       WR        LAC             15.05
# 7         Saquon Barkley    7700       RB        NYG             23.32
# 8           Adam Thielen    7700       WR        MIN             27.82
# 9          Davante Adams    7600       WR         GB             18.62
# 10          James Conner    7500       RB        PIT             20.40
# 11   JuJu Smith-Schuster    7500       WR        PIT             21.90
# 12         Brandin Cooks    7400       WR        LAR             21.20
# 13            A.J. Green    7200       WR        CIN             19.68
# 14      Emmanuel Sanders    7100       WR        DEN             18.92
# 15          Stefon Diggs    7000       WR        MIN             21.25
# 16    Ben Roethlisberger    6900       QB        PIT             25.72
# 17           Tyreek Hill    6900       WR         KC             21.88
# 18             Joe Mixon    6900       RB        CIN             17.80
# 19         Jarvis Landry    6800       WR        CLE             17.30
# 20       Giovani Bernard    6800       RB        CIN             13.82
# 21           Golden Tate    6700       WR        DET             22.95
# 22         Philip Rivers    6700       QB        LAC             23.86
# 23             Matt Ryan    6600       QB        ATL             29.24
# 24       Devonta Freeman    6500       RB        ATL              8.00
# 25             Zach Ertz    6500       TE        PHI             16.68
# 26            Jared Goff    6500       QB        LAR             27.86
# 27          Robert Woods    6500       WR        LAR             20.55
# 28           Corey Davis    6400       WR        TEN             15.55
# 29         Tevin Coleman    6400       RB        ATL             13.60
# ..                   ...     ...      ...        ...               ...
# 267        Neal Sterling    2500       TE        NYJ              2.85
# 268       Eric Tomlinson    2500       TE        NYJ              1.88
# 269     Demetrius Harris    2500       TE         KC              5.40
# 270           Niles Paul    2500       TE        JAX              1.58
# 271  James O'Shaughnessy    2500       TE        JAX              1.88
# 272      Michael Roberts    2500       TE        DET              4.25
# 273       Levine Toilolo    2500       TE        DET              1.22
# 274      Lance Kendricks    2500       TE         GB              1.30
# 275       Marcedes Lewis    2500       TE         GB              0.00
# 276         Darren Fells    2500       TE        CLE              4.40
# 277        Orson Charles    2500       TE        CLE              0.00
# 278        Maxx Williams    2500       TE        BAL              6.15
# 279           Nick Boyle    2500       TE        BAL              4.85
# 280       Scott Simonson    2500       TE        NYG              0.42
# 281         Tyler Eifert    2500       TE        CIN              9.72
# 282         Mike Gesicki    2500       TE        MIA              2.52
# 283           A.J. Derby    2500       TE        MIA              3.83
# 284        Durham Smythe    2500       TE        MIA              0.00
# 285            Lee Smith    2500       TE        OAK              1.32
# 286        Derek Carrier    2500       TE        OAK              1.38
# 287         Virgil Green    2500       TE        LAC              4.28
# 288     Jermaine Gresham    2500       TE        ARI              0.95
# 289        Garrett Celek    2500       TE         SF              2.98
# 290       Joshua Perkins    2500       TE        PHI              2.92
# 291        Tyler Conklin    2500       TE        MIN              0.82
# 292         David Morgan    2500       TE        MIN              2.37
# 293          Will Dissly    2500       TE        SEA              9.65
# 294         Nick Vannett    2500       TE        SEA              3.92
# 295         Tyler Higbee    2500       TE        LAR              3.20
# 296       Gerald Everett    2500       TE        LAR              1.58
#
#                   player  bye_wk  fantasy_pts  pass_2pt  rush_2pt    ...     \
# 0            Todd Gurley    12.0         89.0       0.0       2.0    ...
# 1          Antonio Brown     7.0         44.0       0.0       0.0    ...
# 2          Melvin Gordon     8.0         78.0       0.0       1.0    ...
# 3            Julio Jones     8.0         49.0       0.0       0.0    ...
# 4    Christian McCaffrey     4.0         40.0       0.0       0.0    ...
# 5          Odell Beckham     9.0         33.0       0.0       0.0    ...
# 6           Keenan Allen     NaN          NaN       NaN       NaN    ...
# 7         Saquon Barkley     9.0         60.0       0.0       0.0    ...
# 8           Adam Thielen    10.0         58.0       0.0       0.0    ...
# 9          Davante Adams     7.0         45.0       0.0       0.0    ...
# 10          James Conner     7.0         56.0       0.0       0.0    ...
# 11   JuJu Smith-Schuster     7.0         46.0       0.0       0.0    ...
# 12         Brandin Cooks    12.0         50.0       0.0       0.0    ...
# 13            A.J. Green     9.0         56.0       0.0       0.0    ...
# 14      Emmanuel Sanders    10.0         45.0       0.0       0.0    ...
# 15          Stefon Diggs    10.0         49.0       0.0       0.0    ...
# 16    Ben Roethlisberger     7.0        102.0       2.0       0.0    ...
# 17           Tyreek Hill    12.0         53.0       0.0       0.0    ...
# 18             Joe Mixon     NaN          NaN       NaN       NaN    ...
# 19         Jarvis Landry    11.0         37.0       1.0       0.0    ...
# 20       Giovani Bernard     9.0         38.0       0.0       0.0    ...
# 21           Golden Tate     6.0         54.0       0.0       0.0    ...
# 22         Philip Rivers     8.0        111.0       2.0       0.0    ...
# 23             Matt Ryan     8.0        124.0       2.0       0.0    ...
# 24       Devonta Freeman     NaN          NaN       NaN       NaN    ...
# 25             Zach Ertz     NaN          NaN       NaN       NaN    ...
# 26            Jared Goff    12.0        120.0       1.0       0.0    ...
# 27          Robert Woods    12.0         50.0       0.0       0.0    ...
# 28           Corey Davis     8.0         36.0       0.0       0.0    ...
# 29         Tevin Coleman     8.0         37.0       0.0       0.0    ...
# ..                   ...     ...          ...       ...       ...    ...
# 267        Neal Sterling     NaN          NaN       NaN       NaN    ...
# 268       Eric Tomlinson     NaN          NaN       NaN       NaN    ...
# 269     Demetrius Harris     NaN          NaN       NaN       NaN    ...
# 270           Niles Paul     NaN          NaN       NaN       NaN    ...
# 271  James O'Shaughnessy     NaN          NaN       NaN       NaN    ...
# 272      Michael Roberts     NaN          NaN       NaN       NaN    ...
# 273       Levine Toilolo     NaN          NaN       NaN       NaN    ...
# 274      Lance Kendricks     NaN          NaN       NaN       NaN    ...
# 275       Marcedes Lewis     NaN          NaN       NaN       NaN    ...
# 276         Darren Fells     NaN          NaN       NaN       NaN    ...
# 277        Orson Charles     NaN          NaN       NaN       NaN    ...
# 278        Maxx Williams     NaN          NaN       NaN       NaN    ...
# 279           Nick Boyle     NaN          NaN       NaN       NaN    ...
# 280       Scott Simonson     NaN          NaN       NaN       NaN    ...
# 281         Tyler Eifert     NaN          NaN       NaN       NaN    ...
# 282         Mike Gesicki     NaN          NaN       NaN       NaN    ...
# 283           A.J. Derby     NaN          NaN       NaN       NaN    ...
# 284        Durham Smythe     NaN          NaN       NaN       NaN    ...
# 285            Lee Smith     NaN          NaN       NaN       NaN    ...
# 286        Derek Carrier     NaN          NaN       NaN       NaN    ...
# 287         Virgil Green     NaN          NaN       NaN       NaN    ...
# 288     Jermaine Gresham     NaN          NaN       NaN       NaN    ...
# 289        Garrett Celek     NaN          NaN       NaN       NaN    ...
# 290       Joshua Perkins     NaN          NaN       NaN       NaN    ...
# 291        Tyler Conklin     NaN          NaN       NaN       NaN    ...
# 292         David Morgan     NaN          NaN       NaN       NaN    ...
# 293          Will Dissly     NaN          NaN       NaN       NaN    ...
# 294         Nick Vannett     NaN          NaN       NaN       NaN    ...
# 295         Tyler Higbee     NaN          NaN       NaN       NaN    ...
# 296       Gerald Everett     NaN          NaN       NaN       NaN    ...
#
#        YAC  Gms    Avg    YPG    FD  Team     Yds    TD   Lg  position
# 0    216.0  4.0   4.28   84.5  21.0    LA   338.0   4.0   23        RB
# 1    143.0  4.0   9.38   68.0  14.0   PIT   272.0   3.0  27t     WR/TE
# 2    203.0  4.0   5.11   69.0  13.0   LAC   276.0   2.0   34        RB
# 3    113.0  4.0  11.00    2.8   1.0   ATL    11.0   0.0   11        RB
# 4    151.0  3.0   5.89   90.3  11.0   CAR   271.0   0.0   45        RB
# 5    115.0  4.0   3.00    2.2   1.0   NYG     9.0   0.0   10        RB
# 6    107.0  4.0  11.75   70.5  13.0   LAC   282.0   1.0   25     WR/TE
# 7    230.0  4.0   4.64   65.0  13.0   NYG   260.0   3.0  68t        RB
# 8    149.0  4.0  11.82  118.2  25.0   MIN   473.0   2.0  45t     WR/TE
# 9    124.0  4.0  10.18   71.2  13.0    GB   285.0   3.0   51     WR/TE
# 10   169.0  4.0   3.68   58.0   9.0   PIT   232.0   3.0   27        RB
# 11   201.0  4.0  13.42  104.0  21.0   PIT   416.0   1.0   67     WR/TE
# 12   144.0  4.0   8.00    4.0   1.0    LA    16.0   0.0   10        RB
# 13    81.0  4.0  14.85   74.2  17.0   CIN   297.0   5.0  38t     WR/TE
# 14    95.0  4.0  26.50   13.2   2.0   DEN    53.0   1.0  35t        RB
# 15   157.0  4.0   4.50    2.2   0.0   MIN     9.0   0.0    8        RB
# 16     NaN  4.0   2.30    5.8   4.0   PIT  1414.0   8.0  75t        QB
# 17   146.0  4.0   2.20    2.8   2.0    KC    11.0   0.0    7        RB
# 18    78.0  2.0   4.71   89.5   8.0   CIN   179.0   1.0   27        RB
# 19    73.0  4.0  13.00   78.0  13.0   CLE   312.0   1.0   39     WR/TE
# 20    84.0  4.0   4.56   38.8  12.0   CIN   155.0   3.0   23        RB
# 21   203.0  4.0   9.00    2.2   0.0   DET     9.0   0.0    9        RB
# 22     NaN  4.0   0.29    0.5   1.0   LAC  1156.0  11.0  42t        QB
# 23     NaN  4.0   3.58   10.8   5.0   ATL  1316.0  10.0  75t        QB
# 24    17.0  1.0   6.00   36.0   1.0   ATL    36.0   0.0   20        RB
# 25    98.0  4.0  10.55   81.8  14.0   PHI   327.0   0.0   34     WR/TE
# 26     NaN  4.0   2.75    5.5   2.0    LA  1406.0  11.0  70t        QB
# 27    81.0  4.0   4.75    4.8   1.0    LA    19.0   0.0    8        RB
# 28   130.0  4.0  14.18   78.0  16.0   TEN   312.0   1.0   51     WR/TE
# 29    92.0  4.0   3.89   52.5   6.0   ATL   210.0   1.0   36        RB
# ..     ...  ...    ...    ...   ...   ...     ...   ...  ...       ...
# 267   22.0  2.0   9.00   13.5   1.0   NYJ    27.0   0.0   12     WR/TE
# 268   52.0  4.0  15.00   11.2   2.0   NYJ    45.0   0.0   24     WR/TE
# 269   13.0  3.0  24.00   24.0   3.0    KC    72.0   1.0   35     WR/TE
# 270    9.0  4.0  11.00    8.2   1.0   JAX    33.0   0.0   22     WR/TE
# 271   19.0  4.0  15.00   11.2   3.0   JAX    45.0   0.0   17     WR/TE
# 272    0.0  2.0  15.00    7.5   1.0   DET    15.0   1.0  15t     WR/TE
# 273   21.0  4.0   6.33    4.8   2.0   DET    19.0   0.0    8     WR/TE
# 274   12.0  4.0   7.33    5.5   2.0    GB    22.0   0.0   13     WR/TE
# 275    0.0  4.0   0.00    0.0   0.0    GB     0.0   0.0    0     WR/TE
# 276   43.0  4.0  19.00   19.0   2.0   CLE    76.0   1.0  49t     WR/TE
# 277    0.0  4.0   0.00    0.0   0.0   CLE     0.0   0.0    0     WR/TE
# 278   71.0  4.0   7.00    1.8   1.0   BAL     7.0   0.0    7        RB
# 279   65.0  4.0  11.56   26.0   4.0   BAL   104.0   0.0   25     WR/TE
# 280    2.0  4.0   7.00    1.8   1.0   NYG     7.0   0.0    7     WR/TE
# 281   54.0  4.0  11.93   44.8  10.0   CIN   179.0   1.0   29     WR/TE
# 282   20.0  4.0  10.20   12.8   2.0   MIA    51.0   0.0   19     WR/TE
# 283    2.0  3.0  17.50   11.7   2.0   MIA    35.0   1.0  19t     WR/TE
# 284    0.0  4.0   0.00    0.0   0.0   MIA     0.0   0.0    0     WR/TE
# 285   20.0  4.0   7.67    5.8   1.0   OAK    23.0   0.0   10     WR/TE
# 286   13.0  4.0   8.33    6.2   0.0   OAK    25.0   0.0   12     WR/TE
# 287   50.0  4.0  11.38   22.8   5.0   LAC    91.0   0.0   25     WR/TE
# 288    0.0  2.0   9.00    4.5   1.0   ARI     9.0   0.0    9     WR/TE
# 289   15.0  4.0   9.67    7.2   3.0    SF    29.0   1.0  11t     WR/TE
# 290   16.0  4.0  13.40   16.8   4.0   PHI    67.0   0.0   30     WR/TE
# 291   10.0  4.0   6.50    3.2   1.0   MIN    13.0   0.0    7     WR/TE
# 292   26.0  3.0   7.75   10.3   2.0   MIN    31.0   0.0   13     WR/TE
# 293   93.0  4.0  19.50   39.0   5.0   SEA   156.0   2.0   66     WR/TE
# 294   24.0  4.0   7.44   16.8   4.0   SEA    67.0   0.0   12     WR/TE
# 295   16.0  4.0  12.67    9.5   3.0    LA    38.0   1.0   20     WR/TE
# 296   28.0  4.0  11.00    8.2   1.0    LA    33.0   0.0   17     WR/TE
#
# [297 rows x 34 columns]

# %% [markdown]
# ***

# %% [markdown]
# ### Features to explore:
# - total fantasy points
# - average fantasy points per game
# - TD
# - Yds
# - YPG
# - QB:
#     - Cmp
# - RB:
#     - YPA
# - WR/TE:
#     - Rec
#     - Tar

# %% [markdown]
# ***

# %%
## Find what names in the DK data are not found in the stats data
found, not_found = [], []
dk_names = salaries.Name
for dk in dk_names:
    if dk in stats.player.values:
        found.append(dk)
    else: 
        not_found.append(dk)
len(found), len(not_found)
# Out:
# (297, 137)
