# %%
import pandas as pd

# %%
url_dict = {'fantasy': 'https://www.footballdb.com/fantasy-football/index.html?pos=QB%2CRB%2CWR%2CTE&yr=2018&wk=all&rules=1',
            'QB': 'https://www.footballdb.com/stats/stats.html?mode=P&lg=NFL',
            'RB': 'https://www.footballdb.com/stats/stats.html?lg=NFL&yr=2018&type=reg&mode=R&conf=&limit=all',
            'WR/TE': 'https://www.footballdb.com/stats/stats.html?lg=NFL&yr=2018&type=reg&mode=C&conf=&limit=all'}

# %%
def add_stats(main_df, position):
    """Adds more player stats to the main fantasy stats dataframe.
    
    Args:
    main_df -- (pd.DataFrame) the dataframe you want to add stats to
    position -- (str) one of ['QB', 'RB', 'WR/TE']
    """
    url = url_dict[position]
    df = pd.read_html(url, header=0)[0]
    df['position'] = position

    name_splits = df['Player'].str.split('([a-z])[A-Z]\.', expand=True)
    df['player'] = name_splits.iloc[:, 0] + name_splits.iloc[:, 1]
    del df['Player']

    main_df = pd.merge(main_df, df, on='player', how='outer')
    
    coalesce_cols = [i for i in main_df.columns if '_x' in i]
    for col in coalesce_cols:
        main_df[col[:-2]] = main_df[col].combine_first(main_df[col[:-2]+'_y'])
        del main_df[col]
        del main_df[col[:-2]+'_y']
        
    return(main_df)

# %%
## Read in fantasy data
url = url_dict['fantasy']
stats = pd.read_html(url, header=1)[0].iloc[:, :-1]

cols = ['player', 'bye_wk', 'fantasy_pts', 'pass_att', 'pass_cmp', 'pass_yds', 'pass_td', 'pass_int', 'pass_2pt', 
        'rush_att', 'rush_yds', 'rush_td', 'rush_2pt', 'rec_rcp', 'rec_yds', 'rec_td', 'rec_2pt', 'fumbles_lost']
stats.columns = cols
cols = ['player', 'bye_wk', 'fantasy_pts','pass_2pt', 'rush_2pt','rec_2pt', 'fumbles_lost']
stats = stats[cols]

name_splits = stats['player'].str.split('([a-z])[A-Z]\.', expand=True)
stats['player'] = name_splits.iloc[:, 0] + name_splits.iloc[:, 1]

# %%
## Add stats
stats = add_stats(stats, 'QB')
stats = add_stats(stats, 'RB')
stats = add_stats(stats, 'WR/TE')

# %%
stats.shape
# Out:
# (428, 29)

# %%
stats.columns
# Out:
# Index(['player', 'bye_wk', 'fantasy_pts', 'pass_2pt', 'rush_2pt', 'rec_2pt',
#        'fumbles_lost', 'Cmp', 'Pct', 'YPA', 'TD%', 'Int', 'Int%', 'Sack',
#        'Loss', 'Rate', 'Att', 'Rec', 'Tar', 'YAC', 'Gms', 'Avg', 'YPG', 'FD',
#        'Team', 'Yds', 'TD', 'Lg', 'position'],
#       dtype='object')

# %%
stats
# Out:
#                  player  bye_wk  fantasy_pts  pass_2pt  rush_2pt  rec_2pt  \
# 0       Patrick Mahomes    12.0        140.0       0.0       0.0      0.0
# 1             Matt Ryan     8.0        124.0       2.0       0.0      0.0
# 2            Jared Goff    12.0        120.0       1.0       0.0      0.0
# 3      Ryan Fitzpatrick     5.0        120.0       0.0       0.0      0.0
# 4          Kirk Cousins    10.0        114.0       2.0       0.0      0.0
# 5         Philip Rivers     8.0        111.0       2.0       0.0      0.0
# 6            Drew Brees     6.0        111.0       1.0       0.0      0.0
# 7        Deshaun Watson    10.0        103.0       0.0       0.0      0.0
# 8    Ben Roethlisberger     7.0        102.0       2.0       0.0      0.0
# 9           Andy Dalton     9.0        101.0       0.0       0.0      0.0
# 10         Alvin Kamara     6.0         97.0       0.0       2.0      0.0
# 11          Andrew Luck     9.0         96.0       1.0       0.0      0.0
# 12    Mitchell Trubisky     5.0         92.0       0.0       0.0      0.0
# 13           Joe Flacco    10.0         92.0       0.0       0.0      0.0
# 14        Blake Bortles     9.0         90.0       0.0       0.0      0.0
# 15          Todd Gurley    12.0         89.0       0.0       2.0      0.0
# 16        Aaron Rodgers     7.0         87.0       0.0       0.0      0.0
# 17     Matthew Stafford     6.0         84.0       0.0       0.0      0.0
# 18           Cam Newton     4.0         83.0       0.0       0.0      0.0
# 19            Tom Brady    11.0         81.0       0.0       0.0      0.0
# 20        Melvin Gordon     8.0         78.0       0.0       1.0      1.0
# 21           Derek Carr     7.0         77.0       1.0       0.0      0.0
# 22       Russell Wilson     7.0         71.0       0.0       0.0      0.0
# 23       Ryan Tannehill    11.0         70.0       0.0       0.0      0.0
# 24      Ezekiel Elliott     8.0         67.0       0.0       0.0      0.0
# 25          Eli Manning     9.0         62.0       1.0       0.0      0.0
# 26        Calvin Ridley     8.0         61.0       0.0       0.0      0.0
# 27       Saquon Barkley     9.0         60.0       0.0       0.0      0.0
# 28          Cooper Kupp    12.0         59.0       0.0       0.0      0.0
# 29       Michael Thomas     6.0         58.0       0.0       0.0      0.0
# ..                  ...     ...          ...       ...       ...      ...
# 398      Scott Simonson     NaN          NaN       NaN       NaN      NaN
# 399      Michael Burton     NaN          NaN       NaN       NaN      NaN
# 400       Justin Hunter     NaN          NaN       NaN       NaN      NaN
# 401     Ray Ray McCloud     NaN          NaN       NaN       NaN      NaN
# 402       Tommy Bohanon     NaN          NaN       NaN       NaN      NaN
# 403           Khari Lee     NaN          NaN       NaN       NaN      NaN
# 404        Justin Hardy     NaN          NaN       NaN       NaN      NaN
# 405         J.J. Nelson     NaN          NaN       NaN       NaN      NaN
# 406        Dwayne Allen     NaN          NaN       NaN       NaN      NaN
# 407          Ryan Kelly     NaN          NaN       NaN       NaN      NaN
# 408        Nick Bellore     NaN          NaN       NaN       NaN      NaN
# 409       Orson Charles     NaN          NaN       NaN       NaN      NaN
# 410        Jehu Chesson     NaN          NaN       NaN       NaN      NaN
# 411         Stacy Coley     NaN          NaN       NaN       NaN      NaN
# 412        Mason Crosby     NaN          NaN       NaN       NaN      NaN
# 413          Alan Cross     NaN          NaN       NaN       NaN      NaN
# 414        Rico Gathers     NaN          NaN       NaN       NaN      NaN
# 415      Shelton Gibson     NaN          NaN       NaN       NaN      NaN
# 416      Xavier Grimble     NaN          NaN       NaN       NaN      NaN
# 417         Ryan Hewitt     NaN          NaN       NaN       NaN      NaN
# 418        Blake Jarwin     NaN          NaN       NaN       NaN      NaN
# 419        Taiwan Jones     NaN          NaN       NaN       NaN      NaN
# 420      Marcedes Lewis     NaN          NaN       NaN       NaN      NaN
# 421     Freddie Martino     NaN          NaN       NaN       NaN      NaN
# 422      Riley McCarron     NaN          NaN       NaN       NaN      NaN
# 423       Josh Reynolds     NaN          NaN       NaN       NaN      NaN
# 424        Eric Saubert     NaN          NaN       NaN       NaN      NaN
# 425       Durham Smythe     NaN          NaN       NaN       NaN      NaN
# 426        Mike Wallace     NaN          NaN       NaN       NaN      NaN
# 427          Javon Wims     NaN          NaN       NaN       NaN      NaN
#
#      fumbles_lost    Cmp   Pct   YPA    ...       YAC  Gms    Avg    YPG  \
# 0             0.0   90.0  65.2   8.7    ...       NaN  4.0   2.94   13.2
# 1             0.0   99.0  68.3   9.1    ...       NaN  4.0   3.58   10.8
# 2             0.0   97.0  72.4  10.5    ...       NaN  4.0   2.75    5.5
# 3             0.0   87.0  67.4  10.5    ...       NaN  4.0   3.44   15.5
# 4             3.0  131.0  69.3   7.3    ...       NaN  4.0   5.08   15.2
# 5             0.0  100.0  68.0   7.9    ...       NaN  4.0   0.29    0.5
# 6             0.0  122.0  75.8   8.0    ...       NaN  4.0   0.62    1.2
# 7             1.0   92.0  62.2   8.4    ...       NaN  4.0   6.71   40.2
# 8             2.0  119.0  64.0   7.6    ...       NaN  4.0   2.30    5.8
# 9             0.0  103.0  65.6   7.6    ...       NaN  4.0   5.25    5.2
# 10            0.0    NaN   NaN   NaN    ...     289.0  4.0   4.91   68.8
# 11            1.0  125.0  67.2   6.1    ...       NaN  4.0   5.89   13.2
# 12            2.0   91.0  70.0   7.3    ...       NaN  4.0   6.88   29.2
# 13            1.0  110.0  64.3   7.3    ...       NaN  4.0   0.91    2.5
# 14            0.0   97.0  64.7   7.3    ...       NaN  4.0   7.33   33.0
# 15            1.0    NaN   NaN   NaN    ...     216.0  4.0   4.28   84.5
# 16            1.0   99.0  63.5   7.2    ...       NaN  4.0   6.09   16.8
# 17            1.0  112.0  67.9   7.3    ...       NaN  4.0   5.80    7.2
# 18            0.0   64.0  67.4   6.8    ...       NaN  3.0   4.86   45.3
# 19            1.0   87.0  64.4   6.8    ...       NaN  4.0   2.80    3.5
# 20            0.0    NaN   NaN   NaN    ...     203.0  4.0   5.11   69.0
# 21            0.0  120.0  71.0   8.1    ...       NaN  4.0   0.00    0.0
# 22            1.0   76.0  62.8   7.3    ...       NaN  4.0   3.82   10.5
# 23            2.0   65.0  69.1   8.4    ...       NaN  4.0   4.62   18.5
# 24            1.0    NaN   NaN   NaN    ...     119.0  4.0   5.84  106.5
# 25            2.0  112.0  74.2   7.0    ...       NaN  4.0   1.43    2.5
# 26            0.0    NaN   NaN   NaN    ...      95.0  4.0   4.33    3.2
# 27            0.0    NaN   NaN   NaN    ...     230.0  4.0   4.64   65.0
# 28            0.0    NaN   NaN   NaN    ...     196.0  4.0   4.33    3.2
# 29            2.0    NaN   NaN   NaN    ...     175.0  4.0  10.60  111.2
# ..            ...    ...   ...   ...    ...       ...  ...    ...    ...
# 398           NaN    NaN   NaN   NaN    ...       2.0  4.0   7.00    1.8
# 399           NaN    NaN   NaN   NaN    ...       6.0  3.0   6.00    2.0
# 400           NaN    NaN   NaN   NaN    ...       0.0  1.0   6.00    6.0
# 401           NaN    NaN   NaN   NaN    ...       9.0  2.0   6.00    3.0
# 402           NaN    NaN   NaN   NaN    ...       3.0  4.0   5.00    1.2
# 403           NaN    NaN   NaN   NaN    ...       6.0  2.0   5.00    2.5
# 404           NaN    NaN   NaN   NaN    ...       5.0  4.0   4.00    1.0
# 405           NaN    NaN   NaN   NaN    ...       6.0  4.0   4.00    1.0
# 406           NaN    NaN   NaN   NaN    ...       2.0  4.0  -4.00   -1.0
# 407           NaN    NaN   NaN   NaN    ...      -1.0  4.0  -4.00   -1.0
# 408           NaN    NaN   NaN   NaN    ...       1.0  4.0  -5.00   -1.2
# 409           NaN    NaN   NaN   NaN    ...       0.0  4.0   0.00    0.0
# 410           NaN    NaN   NaN   NaN    ...       0.0  1.0   0.00    0.0
# 411           NaN    NaN   NaN   NaN    ...       0.0  2.0   0.00    0.0
# 412           NaN    NaN   NaN   NaN    ...       0.0  4.0   0.00    0.0
# 413           NaN    NaN   NaN   NaN    ...       0.0  4.0   0.00    0.0
# 414           NaN    NaN   NaN   NaN    ...       0.0  3.0   0.00    0.0
# 415           NaN    NaN   NaN   NaN    ...       0.0  4.0   0.00    0.0
# 416           NaN    NaN   NaN   NaN    ...       0.0  4.0   0.00    0.0
# 417           NaN    NaN   NaN   NaN    ...       0.0  3.0   0.00    0.0
# 418           NaN    NaN   NaN   NaN    ...       0.0  4.0   0.00    0.0
# 419           NaN    NaN   NaN   NaN    ...       0.0  4.0   0.00    0.0
# 420           NaN    NaN   NaN   NaN    ...       0.0  4.0   0.00    0.0
# 421           NaN    NaN   NaN   NaN    ...       0.0  3.0   0.00    0.0
# 422           NaN    NaN   NaN   NaN    ...       0.0  1.0   0.00    0.0
# 423           NaN    NaN   NaN   NaN    ...       0.0  4.0   0.00    0.0
# 424           NaN    NaN   NaN   NaN    ...       0.0  4.0   0.00    0.0
# 425           NaN    NaN   NaN   NaN    ...       0.0  4.0   0.00    0.0
# 426           NaN    NaN   NaN   NaN    ...       0.0  2.0   0.00    0.0
# 427           NaN    NaN   NaN   NaN    ...       0.0  1.0   0.00    0.0
#
#        FD  Team     Yds    TD   Lg  position
# 0     5.0    KC  1200.0  14.0  58t        QB
# 1     5.0   ATL  1316.0  10.0  75t        QB
# 2     2.0    LA  1406.0  11.0  70t        QB
# 3     4.0    TB  1356.0  11.0  75t        QB
# 4     4.0   MIN  1387.0  10.0  75t        QB
# 5     1.0   LAC  1156.0  11.0  42t        QB
# 6     3.0    NO  1295.0   8.0   42        QB
# 7    10.0   HOU  1246.0   7.0  39t        QB
# 8     4.0   PIT  1414.0   8.0  75t        QB
# 9     2.0   CIN  1197.0  11.0   49        QB
# 10   21.0    NO   275.0   5.0  49t        RB
# 11    3.0   IND  1126.0   9.0   42        QB
# 12    6.0   CHI   945.0   8.0   47        QB
# 13    5.0   BAL  1252.0   8.0   71        QB
# 14    7.0   JAX  1095.0   7.0  67t        QB
# 15   21.0    LA   338.0   4.0   23        RB
# 16    6.0    GB  1130.0   7.0  75t        QB
# 17    1.0   DET  1202.0   8.0   67        QB
# 18   11.0   CAR   646.0   5.0  51t        QB
# 19    4.0    NE   918.0   9.0  55t        QB
# 20   13.0   LAC   276.0   2.0   34        RB
# 21    1.0   OAK  1373.0   6.0   66        QB
# 22    4.0   SEA   888.0   7.0   66        QB
# 23    5.0   MIA   787.0   7.0  75t        QB
# 24   20.0   DAL   426.0   2.0   41        RB
# 25    2.0   NYG  1055.0   4.0   37        QB
# 26    1.0   ATL    13.0   0.0    9        RB
# 27   13.0   NYG   260.0   3.0  68t        RB
# 28    2.0    LA    13.0   0.0   12        RB
# 29   23.0    NO   445.0   3.0   35     WR/TE
# ..    ...   ...     ...   ...  ...       ...
# 398   1.0   NYG     7.0   0.0    7     WR/TE
# 399   1.0   CHI     6.0   0.0    6     WR/TE
# 400   1.0   PIT     6.0   0.0    6     WR/TE
# 401   0.0   BUF     6.0   0.0    6     WR/TE
# 402   0.0   JAX     5.0   0.0    5     WR/TE
# 403   0.0   BUF     5.0   0.0    5     WR/TE
# 404   0.0   ATL     4.0   0.0    4     WR/TE
# 405   0.0   ARI     4.0   0.0    4     WR/TE
# 406   0.0    NE    -4.0   0.0   -4     WR/TE
# 407   0.0   IND    -4.0   0.0   -4     WR/TE
# 408   0.0   DET    -5.0   0.0   -5     WR/TE
# 409   0.0   CLE     0.0   0.0    0     WR/TE
# 410   0.0   WAS     0.0   0.0    0     WR/TE
# 411   0.0   MIN     0.0   0.0    0     WR/TE
# 412   0.0    GB     0.0   0.0    0     WR/TE
# 413   0.0    TB     0.0   0.0    0     WR/TE
# 414   0.0   DAL     0.0   0.0    0     WR/TE
# 415   0.0   PHI     0.0   0.0    0     WR/TE
# 416   0.0   PIT     0.0   0.0    0     WR/TE
# 417   0.0   IND     0.0   0.0    0     WR/TE
# 418   0.0   DAL     0.0   0.0    0     WR/TE
# 419   0.0   BUF     0.0   0.0    0     WR/TE
# 420   0.0    GB     0.0   0.0    0     WR/TE
# 421   0.0    TB     0.0   0.0    0     WR/TE
# 422   0.0    NE     0.0   0.0    0     WR/TE
# 423   0.0    LA     0.0   0.0    0     WR/TE
# 424   0.0   ATL     0.0   0.0    0     WR/TE
# 425   0.0   MIA     0.0   0.0    0     WR/TE
# 426   0.0   PHI     0.0   0.0    0     WR/TE
# 427   0.0   CHI     0.0   0.0    0     WR/TE
#
# [428 rows x 29 columns]

# %% [markdown]
# ***

# %%
salaries = pd.read_csv('DKSalaries.csv')
salaries.shape
# Out:
# (74, 9)

# %%
pd.merge(stats[['player', 'fantasy_pts']], salaries[['Name', 'Salary']], left_on='player', right_on='Name', how='inner').shape
# Out:
# (48, 4)

# %% [markdown]
# ***
